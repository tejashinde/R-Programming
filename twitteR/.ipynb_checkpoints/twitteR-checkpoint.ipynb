# %% [markdown]
# ## Loading the Library

# %%
require(twitteR)

# %% [markdown]
# ## Twitter API authentication

# %%
api_key <- "jZc0G65B6MORTqFZyXXlHc3Qt"
 
api_secret <- "TLDNDaDX9PzN5ThTYuiNH3fUb9LyCVeJTB0clI99vNrtkJx8OF"
 
access_token <- "894046754278002690-FWNtGVKuJklyUzZCl2B7pLA9ZNEWbPE"
 
access_token_secret <- "jrzhd3SbikFBqIYtP5gkarb9KMBFvsJBRxGl0Cq7krC9p"

setup_twitter_oauth(api_key, api_secret, access_token, access_token_secret)
# Out:
# [1] "Using direct authentication"

# %% [markdown]
# ## Getting tweets related to the query

# %%
query = 'narendramodi'
# Getting a number of 100 tweets of the queried user handle which in this case is narendramodi
tweets = userTimeline(query , n = 100)

# %% [markdown]
# ## Converting the tweets to a dataframe object

# %%
tweetsDF = twListToDF(tweets)
tail(tweetsDF)
# Out:
#     text
# 95  A paradigm shift in the way projects are initiated and completed. \n\nHappy to share that work on several projects, i… https://t.co/J9jjmDjQoc
# 96  The Integrated Check Post at Moreh, which has been inaugurated today will offer a wide range of facilities to the p… https://t.co/ELXY3eqfdv
# 97  When it comes to the development of the Northeast, our Government has left no stone unturned. \n\nThe contrast with p… https://t.co/JOfExDAA2s
# 98  Defence Minister @nsitharaman's speech in the Parliament demolishes the campaign of calumny on Rafale. Must watch!… https://t.co/WqXhsvdzbt
# 99  Shri @arunjaitley's intervention on Jammu &amp; Kashmir is incisive and informative. Do watch!\nhttps://t.co/pPXV4yewX9
# 100 Happy to be among the people of Assam. Watch my speech at Silchar. https://t.co/QQGuOz6Eh0
#     favorited favoriteCount replyToSN created             truncated replyToSID
# 95  FALSE      6950         NA        2019-01-04 15:25:02  TRUE     NA
# 96  FALSE      7350         NA        2019-01-04 15:21:48  TRUE     NA
# 97  FALSE      9270         NA        2019-01-04 15:20:32  TRUE     NA
# 98  FALSE     30908         NA        2019-01-04 12:44:46  TRUE     NA
# 99  FALSE     11573         NA        2019-01-04 12:39:37 FALSE     NA
# 100 FALSE     11902         NA        2019-01-04 09:56:05 FALSE     NA
#     id                  replyToUID
# 95  1081209900288610305 NA
# 96  1081209083619880960 NA
# 97  1081208766375387136 NA
# 98  1081169567047548928 NA
# 99  1081168270114213889 NA
# 100 1081127114844164096 NA
#     statusSource
# 95  <a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>
# 96  <a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>
# 97  <a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>
# 98  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 99  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 100 <a href="https://periscope.tv" rel="nofollow">Periscope</a>
#     screenName   retweetCount isRetweet retweeted longitude latitude
# 95  narendramodi  1830        FALSE     FALSE     NA        NA
# 96  narendramodi  1986        FALSE     FALSE     NA        NA
# 97  narendramodi  2224        FALSE     FALSE     NA        NA
# 98  narendramodi 10142        FALSE     FALSE     NA        NA
# 99  narendramodi  3157        FALSE     FALSE     NA        NA
# 100 narendramodi  2741        FALSE     FALSE     NA        NA

# %% [markdown]
# ## Text Cleaning

# %%
require(tm)
require(wordcloud)

# %% [markdown]
# ## Building corpus and setting source to be character vectors and do further pre-processing

# %%
corpus = Corpus(VectorSource(tweetsDF$text))

removeURL = function(text) gsub('http[^[:space:]]*' , '' , text)

corpus = tm_map(corpus , tolower)
corpus = tm_map(corpus , removePunctuation)
corpus = tm_map(corpus , removeURL)
corpus = tm_map(corpus , removeWords, stopwords("english"))
corpus = tm_map(corpus , stripWhitespace)
# Out:
# Warning message in tm_map.SimpleCorpus(corpus, tolower):
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(corpus, removePunctuation):
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(corpus, removeURL):
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(corpus, removeWords, stopwords("english")):
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(corpus, stripWhitespace):
# "transformation drops documents"

# %% [markdown]
# ## Converting the corpus to a matrix and sorting the words w.r.t their frequencies

# %%
mine = TermDocumentMatrix(corpus)
mine_matrix = as.matrix(mine)
datavector = sort(rowSums(mine_matrix) , decreasing = TRUE)
frequencyDF = data.frame(word = names(datavector) , freq = datavector)

# %%
head(frequencyDF , 10)
# Out:
#             word                     freq
# …           …                        16
# will        will                     12
# watch       watch                    10
# bjp         bjp                      10
# development development               9
# <U+0915><U+0947>           <U+0915><U+0947>          8
# <U+092E><U+0947><U+0902>           <U+092E><U+0947><U+0902>  7
# <U+0939><U+0948>           <U+0939><U+0948>          7
# <U+0915><U+094B>          <U+0915><U+094B>          6
# projects    projects                  6

# %% [markdown]
# ## Creating a wordcloud

# %%
# set.seed(1234)
wordcloud(words = frequencyDF$word , freq = frequencyDF$freq , min.freq = 1,
          max.words = 200, random.order = FALSE, rot.per = 0.25, 
          colors = brewer.pal(8 , "Dark2"))
# Out:
# plot without title
